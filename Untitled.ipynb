# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint
from nba_api.stats.static import teams
from nba_api.stats.library import data
from nba_api.stats.endpoints import leaguegamefinder

#Creating list of Team Abbreviations
nba_teams = teams.get_teams()
nba_df = pd.DataFrame(nba_teams)
team_ids = nba_df["id"]

#test code I couldn't get to work, lmao
# for team in team_ids:
#     teams_id = [team for team in nba_teams if team['abbreviation'] == team_ids][0]


# This code works but only pulls ONE team at a time, gotta write a script to pull all 30 at once

gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=team_ids[29])
games = gamefinder.get_data_frames()[0]

# doesn't work

# games.groupby(games.SEASON_ID.str[-4:])[['GAME_ID']].count().loc['2008':"2018"]
# ten_years = games[games.SEASON_ID.str[-4:] == '2008':'2018']
# ten_years


games
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION          TEAM_NAME     GAME_ID  \
# 0        22019  1610612766               CHA  Charlotte Hornets  1521900051
# 1        22019  1610612766               CHA  Charlotte Hornets  1521900038
# 2        22019  1610612766               CHA  Charlotte Hornets  1521900021
# 3        22019  1610612766               CHA  Charlotte Hornets  1521900007
# 4        22019  1610612766               CHA  Charlotte Hornets  1521900007
# 5        22018  1610612766               CHA  Charlotte Hornets  0021801222
# 6        22018  1610612766               CHA  Charlotte Hornets  0021801209
# 7        22018  1610612766               CHA  Charlotte Hornets  0021801198
# 8        22018  1610612766               CHA  Charlotte Hornets  0021801180
# 9        22018  1610612766               CHA  Charlotte Hornets  0021801171
# 10       22018  1610612766               CHA  Charlotte Hornets  0021801159
# ...
